# %%
# !pip install psycopg2-binary sqlalchemy pandas
# !pip install python-dotenv
# Out:
# Requirement already satisfied: psycopg2-binary in ./.venv/lib/python3.13/site-packages (2.9.11)
# Requirement already satisfied: sqlalchemy in ./.venv/lib/python3.13/site-packages (2.0.44)
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.13/site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in ./.venv/lib/python3.13/site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.13/site-packages (1.2.1)

# %%
from dotenv import load_dotenv
import os

load_dotenv()

db_user = os.getenv("DB_USER")
db_password = os.getenv("DB_PASSWORD")
db_host = os.getenv("DB_HOST")
db_port = os.getenv("DB_PORT")
db_name = os.getenv("DB_NAME")

#Connecting to Database using SQLalchemy 
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine(f"postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}")
print("Connection successfuly")
# Out:
# Connection successfuly

# %%
#Extracting Data from Fakestore api 
import requests



#Fetching data 
url = "https://fakestoreapi.com/products"
response = requests.get(url)
data = response.json()

# Converting  to DataFrame
df_products = pd.DataFrame(data)
df_products.head()
